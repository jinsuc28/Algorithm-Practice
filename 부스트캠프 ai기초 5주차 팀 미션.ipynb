# %%
import torch
import torch.nn as nn
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-aea8df1df8c4> in <module>
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torchvision.datasets as dset
#       4 import torchvision.transforms as transforms
#       5 from torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'torch'

# %%
import numpy as np
import pandas as pd

# %%
## 1번 문제

training_epochs = 15
batch_size = 100

root= './data'
mnist_train = dset.MNIST(root=root, train=True, transform=transforms.ToTensor(), download=True)
mnist_test = dset.MNIST(root=root, train=False, transform=transforms.ToTensor(), download=True)

# data loader를 직접 구현해보자
train_loader = DataLoader(mnist_train, batch_size, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=False)

##2번 문제
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
linear = torch.nn.Linear(784, 10, bias=True).to(device)
torch.nn.init.normal_(linear.weight)

##3번 문제
criterion = torch.nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.SGD(linear.parameters(), lr=0.1)


##4번 문제
for epoch in range(training_epochs):
  for i, (imgs, labels) in enumerate(train_loader):
    imgs, labels = imgs.to(device), labels.to(device)
    imgs = imgs.view(-1, 28*28)

    outputs = linear(imgs)
    loss = criterion(outputs, labels)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    _, argmax = torch.max(outputs, 1)
    accuracy = (labels == argmax).float().mean()

    if (i+1) % 100 ==0:
      print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'.format(
          epoch+1, training_epochs, i+1, len(train_loader), loss.item(), accuracy.item()*100))


##5번 문제
linear.eval()
with torch.no_grad():
  correct = 0
  total = 0
  for i, (imgs, labels) in enumerate(test_loader):
    imgs, labels = imgs.to(device), labels.to(device)
    imgs = imgs.view(-1,28*28)
    outputs = linear(imgs)
    _, argmax = torch.max(outputs, 1) # max()를 통해 최종 출력이 가장 높은 클래스 선택
    total += imgs.size(0)
    correct += (labels == argmax).sum().item()

    print('Test accuracy for {} images: {:.2f}%'.format(total, correct/total*100))
# Out:
# Epoch [1/15], Step [100/600], Loss: 3.6123, Accuracy: 42.00%
# Epoch [1/15], Step [200/600], Loss: 2.2676, Accuracy: 54.00%
# Epoch [1/15], Step [300/600], Loss: 2.0851, Accuracy: 62.00%
# Epoch [1/15], Step [400/600], Loss: 1.6066, Accuracy: 67.00%
# Epoch [1/15], Step [500/600], Loss: 1.5625, Accuracy: 77.00%
# Epoch [1/15], Step [600/600], Loss: 1.5397, Accuracy: 76.00%
# Epoch [2/15], Step [100/600], Loss: 1.4688, Accuracy: 73.00%
# Epoch [2/15], Step [200/600], Loss: 0.9952, Accuracy: 77.00%
# Epoch [2/15], Step [300/600], Loss: 1.3185, Accuracy: 78.00%
# Epoch [2/15], Step [400/600], Loss: 0.8235, Accuracy: 83.00%
# Epoch [2/15], Step [500/600], Loss: 0.8628, Accuracy: 78.00%
# Epoch [2/15], Step [600/600], Loss: 0.6695, Accuracy: 87.00%
# Epoch [3/15], Step [100/600], Loss: 1.2049, Accuracy: 73.00%
# Epoch [3/15], Step [200/600], Loss: 0.9786, Accuracy: 88.00%
# Epoch [3/15], Step [300/600], Loss: 0.7727, Accuracy: 83.00%
# Epoch [3/15], Step [400/600], Loss: 0.7248, Accuracy: 88.00%
# Epoch [3/15], Step [500/600], Loss: 0.7508, Accuracy: 83.00%
# Epoch [3/15], Step [600/600], Loss: 1.0517, Accuracy: 82.00%
# Epoch [4/15], Step [100/600], Loss: 0.7001, Accuracy: 84.00%
# Test accuracy for 2200 images: 86.41%
# Test accuracy for 2300 images: 86.57%
# Test accuracy for 2400 images: 86.46%
# Test accuracy for 2500 images: 86.64%
# Test accuracy for 2600 images: 86.65%
# Test accuracy for 2700 images: 86.67%
# Test accuracy for 2800 images: 86.79%
# Test accuracy for 2900 images: 86.90%
# Test accuracy for 3000 images: 86.83%
# Test accuracy for 3100 images: 87.00%
# Test accuracy for 3200 images: 86.81%
# Test accuracy for 3300 images: 86.79%
# Test accuracy for 3400 images: 86.94%
# Test accuracy for 3500 images: 87.11%
# Test accuracy for 3600 images: 86.97%
# Test accuracy for 3700 images: 87.11%
# Test accuracy for 3800 images: 87.00%
# Test accuracy for 3900 images: 86.87%
# Test accuracy for 4000 images: 86.88%
# Test accuracy for 4100 images: 86.85%
# Test accuracy for 4200 images: 86.79%
# Test accuracy for 4300 images: 86.77%
# Test accuracy for 4400 images: 86.77%
# Test accuracy for 4500 images: 86.82%
# Test accuracy for 4600 images: 86.78%
# Test accuracy for 4700 images: 86.87%
# Test accuracy for 4800 images: 86.94%
# Test accuracy for 4900 images: 86.86%
# Test accuracy for 5000 images: 86.92%
# Test accuracy for 5100 images: 87.02%
# Test accuracy for 5200 images: 87.12%
# Test accuracy for 5300 images: 87.23%
# Test accuracy for 5400 images: 87.39%
# Test accuracy for 5500 images: 87.53%
# Test accuracy for 5600 images: 87.68%
# Test accuracy for 5700 images: 87.67%
# Test accuracy for 5800 images: 87.71%
# Test accuracy for 5900 images: 87.76%
# Test accuracy for 6000 images: 87.73%
# Test accuracy for 6100 images: 87.70%
# Test accuracy for 6200 images: 87.77%
# Test accuracy for 6300 images: 87.97%
# Test accuracy for 6400 images: 88.08%
# Test accuracy for 6500 images: 88.11%
# Test accuracy for 6600 images: 88.06%
# Test accuracy for 6700 images: 88.07%
# Test accuracy for 6800 images: 88.04%
# Test accuracy for 6900 images: 88.09%
# Test accuracy for 7000 images: 88.19%
# Test accuracy for 7100 images: 88.28%
# Test accuracy for 7200 images: 88.39%
# Test accuracy for 7300 images: 88.45%
# Test accuracy for 7400 images: 88.55%
# Test accuracy for 7500 images: 88.52%
# Test accuracy for 7600 images: 88.57%
# Test accuracy for 7700 images: 88.60%
# Test accuracy for 7800 images: 88.71%
# Test accuracy for 7900 images: 88.62%
# Test accuracy for 8000 images: 88.65%
# Test accuracy for 8100 images: 88.67%
# Test accuracy for 8200 images: 88.78%
# Test accuracy for 8300 images: 88.77%
# Test accuracy for 8400 images: 88.85%
# Test accuracy for 8500 images: 88.94%
# Test accuracy for 8600 images: 89.02%
# Test accuracy for 8700 images: 89.14%
# Test accuracy for 8800 images: 89.26%
# Test accuracy for 8900 images: 89.38%
# Test accuracy for 9000 images: 89.48%
# Test accuracy for 9100 images: 89.42%
# Test accuracy for 9200 images: 89.49%
# Test accuracy for 9300 images: 89.52%
# Test accuracy for 9400 images: 89.56%
# Test accuracy for 9500 images: 89.63%
# Test accuracy for 9600 images: 89.65%
# Test accuracy for 9700 images: 89.61%
# Test accuracy for 9800 images: 89.46%
# Test accuracy for 9900 images: 89.37%
# Test accuracy for 10000 images: 89.32%
